# %%
import pandas as pd
data = pd.read_csv('dataset.csv')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Kehamilan          768 non-null    int64
#  1   Glukosa            768 non-null    int64
#  2   Tekanan Darah      768 non-null    int64
#  3   Ketebalan Kulit    768 non-null    int64
#  4   Insulin            768 non-null    int64
#  5   IMT                768 non-null    float64
#  6   Silsilah Diabetes  768 non-null    float64
#  7   Tahun              768 non-null    int64
#  8   Hasil              768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data
# Out:
#      Kehamilan  Glukosa  Tekanan Darah  Ketebalan Kulit  Insulin   IMT  \
# 0            6      148             72               35        0  33.6
# 1            1       85             66               29        0  26.6
# 2            8      183             64                0        0  23.3
# 3            1       89             66               23       94  28.1
# 4            0      137             40               35      168  43.1
# ..         ...      ...            ...              ...      ...   ...
# 763         10      101             76               48      180  32.9
# 764          2      122             70               27        0  36.8
# 765          5      121             72               23      112  26.2
# 766          1      126             60                0        0  30.1
# 767          1       93             70               31        0  30.4
#
#      Silsilah Diabetes  Tahun  Hasil
# 0                0.627     50      1
# 1                0.351     31      0
# ...

# %%
X = data[data.columns[:8]]
y = data['Hasil']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.svm import SVC

clf = SVC()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83        50
#            1       0.70      0.59      0.64        27
#
#     accuracy                           0.77        77
#    macro avg       0.75      0.73      0.73        77
# weighted avg       0.76      0.77      0.76        77

# %%
df = pd.read_excel("data_input.xlsx")

# %%
df
# Out:
#                         Nama  Kehamilan  Glukosa  Tekanan Darah  \
# 0                 MUH. ERWIN          0       92             62
# 1                  JABAL NUR          0      113             64
# 2                 RIANINGSIH          3      111             56
# 3    RACHMAT AGUS SAHABUDDIN          0      114             68
# 4   MUHAMMAD SAHRUN RAMADHAN          0      193             50
# 5         WAHYUDDIN RAMADHAN          0      155             76
# 6                  RAFIUDDIN          0      191             68
# 7               EGI PRAMUDYA          0      141              0
# 8                   TAMLIHAN          0       95             70
# 9     AIN SIN AL MUDDATSTSIR          0      142             80
# 10            IRMA AYU PUTRI          4      123             62
# 11        ARIF HENDRA WIJAYA          0       96             74
# 12           YUNIAR MULAWATI          5      138              0
# 13             WIRNA LESTARI          3      128             64
# ...

# %%
start_col = 1
end_col = 8

X = df.iloc[:, start_col: end_col + 1]
nama = df.iloc[:, 0]

# %%
nama
# Out:
# 0                   MUH. ERWIN
# 1                    JABAL NUR
# 2                   RIANINGSIH
# 3      RACHMAT AGUS SAHABUDDIN
# 4     MUHAMMAD SAHRUN RAMADHAN
# 5           WAHYUDDIN RAMADHAN
# 6                    RAFIUDDIN
# 7                 EGI PRAMUDYA
# 8                     TAMLIHAN
# 9       AIN SIN AL MUDDATSTSIR
# 10              IRMA AYU PUTRI
# 11          ARIF HENDRA WIJAYA
# 12             YUNIAR MULAWATI
# 13               WIRNA LESTARI
# 14                       ASWIN
# 15                 NUR HALIMAH
# 16                REZQI AMALIA
# 17                FIRMAN KARIM
# 18           FIRSAL PULDRIANSA
# 19             MUH. HAMZA DENI
# 20                     Sunarti
# 21           SUPARMAN SUPABAJA
# 22                    SUPRIADI
# 23                   SYAHRIANI
# 24       SYAHRIL ADITYA HERMAN
# 25                     Syahrul
# 26                  Syahrullah
# 27           SYAJRAH TRI WANDA
# 28          TENRI ANDANI PUTRI
# Name: Nama, dtype: object

# %%
X
# Out:
#     Kehamilan  Glukosa  Tekanan Darah  Ketebalan Kulit  Insulin   IMT  \
# 0           0       92             62                7      258  27.6
# 1           0      113             64               35        0  33.6
# 2           3      111             56               39        0  30.1
# 3           0      114             68               22        0  28.7
# 4           0      193             50               16      375  25.9
# 5           0      155             76               28      150  33.3
# 6           0      191             68               15      130  30.9
# 7           0      141              0                0        0  30.0
# 8           0       95             70               32        0  32.1
# 9           0      142             80               15        0  32.4
# 10          4      123             62                0        0  32.0
# 11          0       96             74               18       67  33.6
# ...

# %%
testDiagnosa = clf.predict(X)

# %%
ey = pd.DataFrame(nama)

ex = pd.DataFrame(testDiagnosa)

# %%
ey.describe()
# Out:
#               Nama
# count           29
# unique          29
# top     MUH. ERWIN
# freq             1

# %%
ex.describe()
# Out:
#                0
# count  29.000000
# mean    0.275862
# std     0.454859
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     1.000000
# max     1.000000

# %%
ey
# Out:
#                         Nama
# 0                 MUH. ERWIN
# 1                  JABAL NUR
# 2                 RIANINGSIH
# 3    RACHMAT AGUS SAHABUDDIN
# 4   MUHAMMAD SAHRUN RAMADHAN
# 5         WAHYUDDIN RAMADHAN
# 6                  RAFIUDDIN
# 7               EGI PRAMUDYA
# 8                   TAMLIHAN
# 9     AIN SIN AL MUDDATSTSIR
# 10            IRMA AYU PUTRI
# 11        ARIF HENDRA WIJAYA
# 12           YUNIAR MULAWATI
# 13             WIRNA LESTARI
# 14                     ASWIN
# 15               NUR HALIMAH
# 16              REZQI AMALIA
# 17              FIRMAN KARIM
# 18         FIRSAL PULDRIANSA
# 19           MUH. HAMZA DENI
# 20                   Sunarti
# 21         SUPARMAN SUPABAJA
# 22                  SUPRIADI
# 23                 SYAHRIANI
# 24     SYAHRIL ADITYA HERMAN
# 25                   Syahrul
# 26                Syahrullah
# 27         SYAJRAH TRI WANDA
# 28        TENRI ANDANI PUTRI

# %%
ex
# Out:
#     0
# 0   0
# 1   0
# 2   0
# 3   0
# 4   1
# 5   1
# 6   1
# 7   1
# 8   0
# 9   1
# 10  0
# 11  0
# 12  1
# 13  0
# 14  0
# 15  0
# 16  0
# 17  0
# 18  1
# 19  0
# 20  1
# 21  0
# 22  0
# 23  0
# 24  0
# 25  0
# 26  0
# 27  0
# 28  0

# %%
# Gabungkan dua DataFrame berdasarkan indeks
result_df = pd.concat([ey, ex[0]], axis=1)

# Ganti nama kolom '0' menjadi 'Hasil'
result_df.rename(columns={0: 'Hasil'}, inplace=True)

# Ganti nilai 1 dengan 'positif' dan nilai 0 dengan 'negatif' dalam kolom 'hasil'
result_df['Hasil'] = result_df['Hasil'].replace({1: 'positif', 0: 'negatif'})

# Cetak hasil
print(result_df)
# Out:
#                         Nama    Hasil
# 0                 MUH. ERWIN  negatif
# 1                  JABAL NUR  negatif
# 2                 RIANINGSIH  negatif
# 3    RACHMAT AGUS SAHABUDDIN  negatif
# 4   MUHAMMAD SAHRUN RAMADHAN  positif
# 5         WAHYUDDIN RAMADHAN  positif
# 6                  RAFIUDDIN  positif
# 7               EGI PRAMUDYA  positif
# 8                   TAMLIHAN  negatif
# 9     AIN SIN AL MUDDATSTSIR  positif
# 10            IRMA AYU PUTRI  negatif
# 11        ARIF HENDRA WIJAYA  negatif
# 12           YUNIAR MULAWATI  positif
# 13             WIRNA LESTARI  negatif
# 14                     ASWIN  negatif
# 15               NUR HALIMAH  negatif
# 16              REZQI AMALIA  negatif
# 17              FIRMAN KARIM  negatif
# 18         FIRSAL PULDRIANSA  positif
# 19           MUH. HAMZA DENI  negatif
# 20                   Sunarti  positif
# 21         SUPARMAN SUPABAJA  negatif
# 22                  SUPRIADI  negatif
# 23                 SYAHRIANI  negatif
# ...

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Nama    29 non-null     object
#  1   Hasil   29 non-null     object
# dtypes: object(2)
# memory usage: 592.0+ bytes

# %%
result_df.to_excel('hasil_diagnosa.xlsx', index=False)
